# %% [markdown]
# <a href="https://colab.research.google.com/github/Ananya-AJ/CMPE255-SafeDose/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import libraries
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')

# reading the data
drug = pd.read_csv('/content/drive/MyDrive/Master/Fall 2022/CMPE 255/Project/drug_data.csv')
# Out:
# Mounted at /content/drive

# %%
drug.shape
# Out:
# (218950, 54)

# %%
drug
# Out:
#         Unnamed: 0  CASEID  DRUGID_1  CATID_1_1  CATID_2_1  CATID_3_1  \
# 0                0       1       865        105        110       2005
# 1                1       2      2077         81         82        283
# 2                2       3      2313          1         12         -7
# 3                3       4       234        358         99        215
# 4                4       5       865        105        110       2005
# ...            ...     ...       ...        ...        ...        ...
# 218945      218945  229207       227         40         49        156
# 218946      218946  229208       179         57         67         69
# 218947      218947  229209        86          1         13        225
# 218948      218948  229210        85          1         13        224
# 218949      218949  229211       940        122        132         -7
#
#         ROUTE_1  TOXTEST_1  sdled_1_1  sdled_2_1  ...  QUARTER  DAYPART  \
# ...

# %%
drug.head()
# Out:
#    Unnamed: 0  CASEID  DRUGID_1  CATID_1_1  CATID_2_1  CATID_3_1  ROUTE_1  \
# 0           0       1       865        105        110       2005        1
# 1           1       2      2077         81         82        283       -8
# 2           2       3      2313          1         12         -7       -8
# 3           3       4       234        358         99        215        2
# 4           4       5       865        105        110       2005        1
#
#    TOXTEST_1  sdled_1_1  sdled_2_1  ...  QUARTER  DAYPART  NUMSUBS  CASETYPE  \
# 0          2          1        2.0  ...        4        1        2         8
# 1          2         17       67.0  ...        3        4        1         4
# 2          2         17       64.0  ...        4        3        1         4
# 3          2         17       73.0  ...        2        2        1         4
# 4          2          1        2.0  ...        3        4        3         8
#
#    DISPOSITION  ALLABUSE  METRO  AGECAT  SEX  RACE
# ...

# %%
drug.tail()
# Out:
#         Unnamed: 0  CASEID  DRUGID_1  CATID_1_1  CATID_2_1  CATID_3_1  \
# 218945      218945  229207       227         40         49        156
# 218946      218946  229208       179         57         67         69
# 218947      218947  229209        86          1         13        225
# 218948      218948  229210        85          1         13        224
# 218949      218949  229211       940        122        132         -7
#
#         ROUTE_1  TOXTEST_1  sdled_1_1  sdled_2_1  ...  QUARTER  DAYPART  \
# 218945       -8          2         17       57.0  ...        3        4
# 218946       -8          2         17       33.0  ...        3        3
# 218947       -8          2         17       64.0  ...        3        4
# 218948       -8          2         17       64.0  ...        2        2
# 218949       -8          2         17       50.0  ...        1        1
#
#         NUMSUBS  CASETYPE  DISPOSITION  ALLABUSE  METRO  AGECAT  SEX  RACE
# ...

# %%
drug.dtypes
# Out:
# Unnamed: 0        int64
# CASEID            int64
# DRUGID_1          int64
# CATID_1_1         int64
# CATID_2_1         int64
# CATID_3_1         int64
# ROUTE_1           int64
# TOXTEST_1         int64
# sdled_1_1         int64
# sdled_2_1       float64
# sdled_3_1       float64
# sdled_4_1       float64
# sdled_5_1       float64
# sdled_6_1       float64
# DRUGID_2          int64
# CATID_1_2         int64
# CATID_2_2         int64
# CATID_3_2         int64
# ROUTE_2           int64
# TOXTEST_2         int64
# sdled_1_2         int64
# sdled_2_2       float64
# sdled_3_2       float64
# sdled_4_2       float64
# sdled_5_2       float64
# sdled_6_2       float64
# DRUGID_3          int64
# CATID_1_3         int64
# CATID_2_3         int64
# CATID_3_3         int64
# ROUTE_3           int64
# TOXTEST_3         int64
# sdled_1_3         int64
# sdled_2_3       float64
# sdled_3_3       float64
# sdled_4_3       float64
# sdled_5_3       float64
# sdled_6_3       float64
# ...

# %%
drug.describe()
# Out:
#           Unnamed: 0         CASEID       DRUGID_1      CATID_1_1  \
# count  218950.000000  218950.000000  218950.000000  218950.000000
# mean   109474.500000  114600.514917    1031.626600     168.844745
# std     63205.565057   66150.414953     751.893793     372.704136
# min         0.000000       1.000000       1.000000       1.000000
# 25%     54737.250000   57326.250000     339.000000      57.000000
# 50%    109474.500000  114570.500000     865.000000     105.000000
# 75%    164211.750000  171882.750000    1255.000000     105.000000
# max    218949.000000  229211.000000    2558.000000    2041.000000
#
#            CATID_2_1      CATID_3_1        ROUTE_1      TOXTEST_1  \
# count  218950.000000  218950.000000  218950.000000  218950.000000
# mean      106.481192    1071.883444      -4.521096       1.503421
# std       169.491369     965.135770       6.415982       2.056819
# min        -7.000000      -7.000000      -9.000000      -9.000000
# ...

# %%
drug.isnull().sum()
# Out:
# Unnamed: 0      0
# CASEID          0
# DRUGID_1        0
# CATID_1_1       0
# CATID_2_1       0
# CATID_3_1       0
# ROUTE_1         0
# TOXTEST_1       0
# sdled_1_1       0
# sdled_2_1       0
# sdled_3_1       0
# sdled_4_1       0
# sdled_5_1       0
# sdled_6_1       0
# DRUGID_2        0
# CATID_1_2       0
# CATID_2_2       0
# CATID_3_2       0
# ROUTE_2         0
# TOXTEST_2       0
# sdled_1_2       0
# sdled_2_2       0
# sdled_3_2       0
# sdled_4_2       0
# sdled_5_2       0
# sdled_6_2       0
# DRUGID_3        0
# CATID_1_3       0
# CATID_2_3       0
# CATID_3_3       0
# ROUTE_3         0
# TOXTEST_3       0
# sdled_1_3       0
# sdled_2_3       0
# sdled_3_3       0
# sdled_4_3       0
# sdled_5_3       0
# sdled_6_3       0
# ALCOHOL         0
# NONALCILL       0
# PHARMA          0
# NONMEDPHARMA    0
# CASEWGT         0
# YEAR            0
# QUARTER         0
# DAYPART         0
# NUMSUBS         0
# CASETYPE        0
# DISPOSITION     0
# ALLABUSE        0
# ...

# %%
drug.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 218950 entries, 0 to 218949
# Data columns (total 54 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0    218950 non-null  int64
#  1   CASEID        218950 non-null  int64
#  2   DRUGID_1      218950 non-null  int64
#  3   CATID_1_1     218950 non-null  int64
#  4   CATID_2_1     218950 non-null  int64
#  5   CATID_3_1     218950 non-null  int64
#  6   ROUTE_1       218950 non-null  int64
#  7   TOXTEST_1     218950 non-null  int64
#  8   sdled_1_1     218950 non-null  int64
#  9   sdled_2_1     218950 non-null  float64
#  10  sdled_3_1     218950 non-null  float64
#  11  sdled_4_1     218950 non-null  float64
#  12  sdled_5_1     218950 non-null  float64
#  13  sdled_6_1     218950 non-null  float64
#  14  DRUGID_2      218950 non-null  int64
#  15  CATID_1_2     218950 non-null  int64
#  16  CATID_2_2     218950 non-null  int64
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
drug.ALLABUSE.value_counts().nlargest(10).plot(kind='bar', figsize=(15,5))
plt.title("ALLABUSE")
# Out:
# Text(0.5, 1.0, 'ALLABUSE')

# %%
drug.METRO.hist(bins=6,color='green');
plt.title("METRO")
# Out:
# Text(0.5, 1.0, 'METRO')

# %%
drug['AGECAT'].value_counts().plot.pie(figsize=(6, 6), autopct='%.2f')
plt.title("AGECAT")
# Out:
# Text(0.5, 1.0, 'AGECAT')

# %%
drug.SEX.value_counts().nlargest(10).plot(kind='bar', figsize=(15,5))
plt.title("SEX")
# Out:
# Text(0.5, 1.0, 'SEX')

# %%
drug['SEX'].value_counts().plot(kind='bar',color='purple')
plt.title("SEX")
# Out:
# Text(0.5, 1.0, 'SEX')

# %%
drug['RACE'].value_counts().plot.pie(figsize=(6, 6), autopct='%.2f')
plt.title("RACE")
# Out:
# Text(0.5, 1.0, 'RACE')

# %%
drug['ALCOHOL'].value_counts().plot(kind='bar',color='purple')
plt.title("ALCOHOL")
# Out:
# Text(0.5, 1.0, 'ALCOHOL')

# %%
import seaborn as sns
corr = drug.corr()
sns.set_context("notebook", font_scale=1.0, rc={"lines.linewidth": 2.5})
plt.figure(figsize=(100,100))
a = sns.heatmap(corr, annot=True, fmt='.2f')
rotx = a.set_xticklabels(a.get_xticklabels(), rotation=90)
roty = a.set_yticklabels(a.get_yticklabels(), rotation=30)

# %%
plt.rcParams['figure.figsize']=(23,10)
ax = sns.boxplot(x="CASEWGT", data=drug)

# %%
plt.rcParams['figure.figsize']=(23,10)
ax = sns.boxplot(x="QUARTER", data=drug)

# %%
plt.rcParams['figure.figsize']=(23,10)
ax = sns.boxplot(x="DAYPART", data=drug)

# %%
plt.rcParams['figure.figsize']=(23,10)
ax = sns.boxplot(x="NUMSUBS", data=drug)

# %%
plt.rcParams['figure.figsize']=(23,10)
ax = sns.boxplot(x="CASETYPE", data=drug)

# %%
plt.rcParams['figure.figsize']=(23,10)
ax = sns.boxplot(x="DISPOSITION", data=drug)
